# %% [markdown]
# # Charlie Coder

# %%
import trifacta as tf

# %%
import pandas as pd
df_people = pd.read_csv('people.csv')
df_zipcodes = pd.read_csv('uszips.csv')
wf = tf.wrangle(df_people, df_zipcodes, flow_name="DIY Data - Episode 3 - Charlie Coder")
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Registering aliases for input dataframes as per their input order.
# Alias not found, new alias assigned : dataframe
# Alias not found, new alias assigned : dataframe_1

# %%
wf.open()
# Out:
# Opening https://cloud.trifacta.com/flows/132831
# 'https://cloud.trifacta.com/flows/132831'

# %% [markdown]
# ### Generate pandas code

# %%
wf.get_pandas(add_to_next_cell=True,recipe_name='pyfacta_dataframe')

# %%
from trifacta.transform_functions.function_definitions import Matches, Replace, is_empty, to_integer
import pandas as pd
import numpy as np


def run_transforms(dataframe_1=None, dataframe=None):
    if (dataframe_1 is None):
        dataframe_1 = pd.read_csv('/insert/dataset/location/here/',
                                  skip_blank_lines=False,
                                  lineterminator='\n',
                                  dtype=str,
                                  encoding='UTF-8')
    dataframe_1.columns = [
        'column', 'column_1', 'column_2', 'column_3', 'column_4', 'column_5',
        'column_6', 'column_7', 'column_8', 'column_9', 'column_10',
        'column_11', 'column_12', 'column_13', 'column_14', 'column_15',
        'column_16', 'column_17'
    ]
    matches1 = Matches('^()(")()', False)
    matches2 = Matches('()(")()$', False)
    replace1 = Replace('^"|"$', '', True, False)
    dataframe_1 = pd.DataFrame({
        'new_column':
            pd.DataFrame.where(
                pd.Series(dataframe_1['column'].str.strip().apply(
                    (lambda x: replace1.exec(x))),
                          index=dataframe_1.index),
                pd.Series((dataframe_1['column'].str.strip().apply(
                    (lambda x: matches1.exec(x))) &
                           dataframe_1['column'].str.strip().apply(
                               (lambda x: matches2.exec(x)))),
                          index=dataframe_1.index),
                pd.Series(dataframe_1['column'], index=dataframe_1.index)),
        'new_column_1':
            pd.DataFrame.where(
                pd.Series(dataframe_1['column_1'].str.strip().apply(
                    (lambda x: replace1.exec(x))),
                          index=dataframe_1.index),
                pd.Series((dataframe_1['column_1'].str.strip().apply(
                    (lambda x: matches1.exec(x))) &
                           dataframe_1['column_1'].str.strip().apply(
                               (lambda x: matches2.exec(x)))),
                          index=dataframe_1.index),
                pd.Series(dataframe_1['column_1'], index=dataframe_1.index)),
        'new_column_2':
            pd.DataFrame.where(
                pd.Series(dataframe_1['column_2'].str.strip().apply(
                    (lambda x: replace1.exec(x))),
                          index=dataframe_1.index),
                pd.Series((dataframe_1['column_2'].str.strip().apply(
                    (lambda x: matches1.exec(x))) &
                           dataframe_1['column_2'].str.strip().apply(
                               (lambda x: matches2.exec(x)))),
                          index=dataframe_1.index),
                pd.Series(dataframe_1['column_2'], index=dataframe_1.index)),
        'new_column_3':
            pd.DataFrame.where(
                pd.Series(dataframe_1['column_3'].str.strip().apply(
                    (lambda x: replace1.exec(x))),
                          index=dataframe_1.index),
                pd.Series((dataframe_1['column_3'].str.strip().apply(
                    (lambda x: matches1.exec(x))) &
                           dataframe_1['column_3'].str.strip().apply(
                               (lambda x: matches2.exec(x)))),
                          index=dataframe_1.index),
                pd.Series(dataframe_1['column_3'], index=dataframe_1.index)),
        'new_column_4':
            pd.DataFrame.where(
                pd.Series(dataframe_1['column_4'].str.strip().apply(
                    (lambda x: replace1.exec(x))),
                          index=dataframe_1.index),
                pd.Series((dataframe_1['column_4'].str.strip().apply(
                    (lambda x: matches1.exec(x))) &
                           dataframe_1['column_4'].str.strip().apply(
                               (lambda x: matches2.exec(x)))),
                          index=dataframe_1.index),
                pd.Series(dataframe_1['column_4'], index=dataframe_1.index)),
        'new_column_5':
            pd.DataFrame.where(
                pd.Series(dataframe_1['column_5'].str.strip().apply(
                    (lambda x: replace1.exec(x))),
                          index=dataframe_1.index),
                pd.Series((dataframe_1['column_5'].str.strip().apply(
                    (lambda x: matches1.exec(x))) &
                           dataframe_1['column_5'].str.strip().apply(
                               (lambda x: matches2.exec(x)))),
                          index=dataframe_1.index),
                pd.Series(dataframe_1['column_5'], index=dataframe_1.index)),
        'new_column_6':
            pd.DataFrame.where(
                pd.Series(dataframe_1['column_6'].str.strip().apply(
                    (lambda x: replace1.exec(x))),
                          index=dataframe_1.index),
                pd.Series((dataframe_1['column_6'].str.strip().apply(
                    (lambda x: matches1.exec(x))) &
                           dataframe_1['column_6'].str.strip().apply(
                               (lambda x: matches2.exec(x)))),
                          index=dataframe_1.index),
                pd.Series(dataframe_1['column_6'], index=dataframe_1.index)),
        'new_column_7':
            pd.DataFrame.where(
                pd.Series(dataframe_1['column_7'].str.strip().apply(
                    (lambda x: replace1.exec(x))),
                          index=dataframe_1.index),
                pd.Series((dataframe_1['column_7'].str.strip().apply(
                    (lambda x: matches1.exec(x))) &
                           dataframe_1['column_7'].str.strip().apply(
                               (lambda x: matches2.exec(x)))),
                          index=dataframe_1.index),
                pd.Series(dataframe_1['column_7'], index=dataframe_1.index)),
        'new_column_8':
            pd.DataFrame.where(
                pd.Series(dataframe_1['column_8'].str.strip().apply(
                    (lambda x: replace1.exec(x))),
                          index=dataframe_1.index),
                pd.Series((dataframe_1['column_8'].str.strip().apply(
                    (lambda x: matches1.exec(x))) &
                           dataframe_1['column_8'].str.strip().apply(
                               (lambda x: matches2.exec(x)))),
                          index=dataframe_1.index),
                pd.Series(dataframe_1['column_8'], index=dataframe_1.index)),
        'new_column_9':
            pd.DataFrame.where(
                pd.Series(dataframe_1['column_9'].str.strip().apply(
                    (lambda x: replace1.exec(x))),
                          index=dataframe_1.index),
                pd.Series((dataframe_1['column_9'].str.strip().apply(
                    (lambda x: matches1.exec(x))) &
                           dataframe_1['column_9'].str.strip().apply(
                               (lambda x: matches2.exec(x)))),
                          index=dataframe_1.index),
                pd.Series(dataframe_1['column_9'], index=dataframe_1.index)),
        'new_column_10':
            pd.DataFrame.where(
                pd.Series(dataframe_1['column_10'].str.strip().apply(
                    (lambda x: replace1.exec(x))),
                          index=dataframe_1.index),
                pd.Series((dataframe_1['column_10'].str.strip().apply(
                    (lambda x: matches1.exec(x))) &
                           dataframe_1['column_10'].str.strip().apply(
                               (lambda x: matches2.exec(x)))),
                          index=dataframe_1.index),
                pd.Series(dataframe_1['column_10'], index=dataframe_1.index)),
        'new_column_11':
            pd.DataFrame.where(
                pd.Series(dataframe_1['column_11'].str.strip().apply(
                    (lambda x: replace1.exec(x))),
                          index=dataframe_1.index),
                pd.Series((dataframe_1['column_11'].str.strip().apply(
                    (lambda x: matches1.exec(x))) &
                           dataframe_1['column_11'].str.strip().apply(
                               (lambda x: matches2.exec(x)))),
                          index=dataframe_1.index),
                pd.Series(dataframe_1['column_11'], index=dataframe_1.index)),
        'new_column_12':
            pd.DataFrame.where(
                pd.Series(dataframe_1['column_12'].str.strip().apply(
                    (lambda x: replace1.exec(x))),
                          index=dataframe_1.index),
                pd.Series((dataframe_1['column_12'].str.strip().apply(
                    (lambda x: matches1.exec(x))) &
                           dataframe_1['column_12'].str.strip().apply(
                               (lambda x: matches2.exec(x)))),
                          index=dataframe_1.index),
                pd.Series(dataframe_1['column_12'], index=dataframe_1.index)),
        'new_column_13':
            pd.DataFrame.where(
                pd.Series(dataframe_1['column_13'].str.strip().apply(
                    (lambda x: replace1.exec(x))),
                          index=dataframe_1.index),
                pd.Series((dataframe_1['column_13'].str.strip().apply(
                    (lambda x: matches1.exec(x))) &
                           dataframe_1['column_13'].str.strip().apply(
                               (lambda x: matches2.exec(x)))),
                          index=dataframe_1.index),
                pd.Series(dataframe_1['column_13'], index=dataframe_1.index)),
        'new_column_14':
            pd.DataFrame.where(
                pd.Series(dataframe_1['column_14'].str.strip().apply(
                    (lambda x: replace1.exec(x))),
                          index=dataframe_1.index),
                pd.Series((dataframe_1['column_14'].str.strip().apply(
                    (lambda x: matches1.exec(x))) &
                           dataframe_1['column_14'].str.strip().apply(
                               (lambda x: matches2.exec(x)))),
                          index=dataframe_1.index),
                pd.Series(dataframe_1['column_14'], index=dataframe_1.index)),
        'new_column_15':
            pd.DataFrame.where(
                pd.Series(dataframe_1['column_15'].str.strip().apply(
                    (lambda x: replace1.exec(x))),
                          index=dataframe_1.index),
                pd.Series((dataframe_1['column_15'].str.strip().apply(
                    (lambda x: matches1.exec(x))) &
                           dataframe_1['column_15'].str.strip().apply(
                               (lambda x: matches2.exec(x)))),
                          index=dataframe_1.index),
                pd.Series(dataframe_1['column_15'], index=dataframe_1.index)),
        'new_column_16':
            pd.DataFrame.where(
                pd.Series(dataframe_1['column_16'].str.strip().apply(
                    (lambda x: replace1.exec(x))),
                          index=dataframe_1.index),
                pd.Series((dataframe_1['column_16'].str.strip().apply(
                    (lambda x: matches1.exec(x))) &
                           dataframe_1['column_16'].str.strip().apply(
                               (lambda x: matches2.exec(x)))),
                          index=dataframe_1.index),
                pd.Series(dataframe_1['column_16'], index=dataframe_1.index)),
        'new_column_17':
            pd.DataFrame.where(
                pd.Series(dataframe_1['column_17'].str.strip().apply(
                    (lambda x: replace1.exec(x))),
                          index=dataframe_1.index),
                pd.Series((dataframe_1['column_17'].str.strip().apply(
                    (lambda x: matches1.exec(x))) &
                           dataframe_1['column_17'].str.strip().apply(
                               (lambda x: matches2.exec(x)))),
                          index=dataframe_1.index),
                pd.Series(dataframe_1['column_17'], index=dataframe_1.index))
    })
    replace2 = Replace('""', '"', True, False)
    dataframe_1 = pd.DataFrame({
        'new_column_18':
            dataframe_1['new_column'].apply((lambda x: replace2.exec(x))),
        'new_column_19':
            dataframe_1['new_column_1'].apply((lambda x: replace2.exec(x))),
        'new_column_20':
            dataframe_1['new_column_2'].apply((lambda x: replace2.exec(x))),
        'new_column_21':
            dataframe_1['new_column_3'].apply((lambda x: replace2.exec(x))),
        'new_column_22':
            dataframe_1['new_column_4'].apply((lambda x: replace2.exec(x))),
        'new_column_23':
            dataframe_1['new_column_5'].apply((lambda x: replace2.exec(x))),
        'new_column_24':
            dataframe_1['new_column_6'].apply((lambda x: replace2.exec(x))),
        'new_column_25':
            dataframe_1['new_column_7'].apply((lambda x: replace2.exec(x))),
        'new_column_26':
            dataframe_1['new_column_8'].apply((lambda x: replace2.exec(x))),
        'new_column_27':
            dataframe_1['new_column_9'].apply((lambda x: replace2.exec(x))),
        'new_column_28':
            dataframe_1['new_column_10'].apply((lambda x: replace2.exec(x))),
        'new_column_29':
            dataframe_1['new_column_11'].apply((lambda x: replace2.exec(x))),
        'new_column_30':
            dataframe_1['new_column_12'].apply((lambda x: replace2.exec(x))),
        'new_column_31':
            dataframe_1['new_column_13'].apply((lambda x: replace2.exec(x))),
        'new_column_32':
            dataframe_1['new_column_14'].apply((lambda x: replace2.exec(x))),
        'new_column_33':
            dataframe_1['new_column_15'].apply((lambda x: replace2.exec(x))),
        'new_column_34':
            dataframe_1['new_column_16'].apply((lambda x: replace2.exec(x))),
        'new_column_35':
            dataframe_1['new_column_17'].apply((lambda x: replace2.exec(x)))
    })
    dataframe_1 = dataframe_1.loc[((((
        (pd.DataFrame.where(
            pd.Series(True, index=dataframe_1.index),
            pd.Series(dataframe_1['new_column_18'].apply(
                (lambda x: is_empty(x))),
                      index=dataframe_1.index),
            pd.Series(
                (dataframe_1['new_column_18'].astype('str').mask(
                    dataframe_1['new_column_18'].isnull(), pd.NA) != 'zip'),
                index=dataframe_1.index)) |
         pd.DataFrame.where(
             pd.Series(True, index=dataframe_1.index),
             pd.Series(dataframe_1['new_column_19'].apply(
                 (lambda x: is_empty(x))),
                       index=dataframe_1.index),
             pd.Series((dataframe_1['new_column_19'].astype('str').mask(
                 dataframe_1['new_column_19'].isnull(), pd.NA) != 'lat'),
                       index=dataframe_1.index))) |
        (pd.DataFrame.where(
            pd.Series(True, index=dataframe_1.index),
            pd.Series(dataframe_1['new_column_20'].apply(
                (lambda x: is_empty(x))),
                      index=dataframe_1.index),
            pd.Series((dataframe_1['new_column_20'].astype('str').mask(
                dataframe_1['new_column_20'].isnull(), pd.NA) != 'lng'),
                      index=dataframe_1.index)) |
         pd.DataFrame.where(
             pd.Series(True, index=dataframe_1.index),
             pd.Series(dataframe_1['new_column_21'].apply(
                 (lambda x: is_empty(x))),
                       index=dataframe_1.index),
             pd.Series((dataframe_1['new_column_21'].astype('str').mask(
                 dataframe_1['new_column_21'].isnull(), pd.NA) != 'city'),
                       index=dataframe_1.index)))
    ) | ((pd.DataFrame.where(
        pd.Series(True, index=dataframe_1.index),
        pd.Series(dataframe_1['new_column_22'].apply((lambda x: is_empty(x))),
                  index=dataframe_1.index),
        pd.Series((dataframe_1['new_column_22'].astype('str').mask(
            dataframe_1['new_column_22'].isnull(), pd.NA) != 'state_id'),
                  index=dataframe_1.index)) | pd.DataFrame.where(
                      pd.Series(True, index=dataframe_1.index),
                      pd.Series(dataframe_1['new_column_23'].apply(
                          (lambda x: is_empty(x))),
                                index=dataframe_1.index),
                      pd.Series(
                          (dataframe_1['new_column_23'].astype('str').mask(
                              dataframe_1['new_column_23'].isnull(), pd.NA) !=
                           'state_name'),
                          index=dataframe_1.index))) |
         (pd.DataFrame.where(
             pd.Series(True, index=dataframe_1.index),
             pd.Series(dataframe_1['new_column_24'].apply(
                 (lambda x: is_empty(x))),
                       index=dataframe_1.index),
             pd.Series(
                 (dataframe_1['new_column_24'].astype('str').mask(
                     dataframe_1['new_column_24'].isnull(), pd.NA) != 'zcta'),
                 index=dataframe_1.index)) | pd.DataFrame.where(
                     pd.Series(True, index=dataframe_1.index),
                     pd.Series(dataframe_1['new_column_25'].apply(
                         (lambda x: is_empty(x))),
                               index=dataframe_1.index),
                     pd.Series((dataframe_1['new_column_25'].astype('str').mask(
                         dataframe_1['new_column_25'].isnull(), pd.NA) !=
                                'parent_zcta'),
                               index=dataframe_1.index)))
        )) | (((pd.DataFrame.where(
            pd.Series(True, index=dataframe_1.index),
            pd.Series(dataframe_1['new_column_26'].apply(
                (lambda x: is_empty(x))),
                      index=dataframe_1.index),
            pd.Series((dataframe_1['new_column_26'].astype('str').mask(
                dataframe_1['new_column_26'].isnull(), pd.NA) != 'population'),
                      index=dataframe_1.index)) | pd.DataFrame.where(
                          pd.Series(True, index=dataframe_1.index),
                          pd.Series(dataframe_1['new_column_27'].apply(
                              (lambda x: is_empty(x))),
                                    index=dataframe_1.index),
                          pd.Series(
                              (dataframe_1['new_column_27'].astype('str').mask(
                                  dataframe_1['new_column_27'].isnull(), pd.NA)
                               != 'density'),
                              index=dataframe_1.index))) |
               (pd.DataFrame.where(
                   pd.Series(True, index=dataframe_1.index),
                   pd.Series(dataframe_1['new_column_28'].apply(
                       (lambda x: is_empty(x))),
                             index=dataframe_1.index),
                   pd.Series(
                       (dataframe_1['new_column_28'].astype('str').mask(
                           dataframe_1['new_column_28'].isnull(), pd.NA) !=
                        'county_fips'),
                       index=dataframe_1.index)) | pd.DataFrame.where(
                           pd.Series(True, index=dataframe_1.index),
                           pd.Series(dataframe_1['new_column_29'].apply(
                               (lambda x: is_empty(x))),
                                     index=dataframe_1.index),
                           pd.Series(
                               (dataframe_1['new_column_29'].astype('str').mask(
                                   dataframe_1['new_column_29'].isnull(), pd.NA)
                                != 'county_name'),
                               index=dataframe_1.index)))) |
              ((pd.DataFrame.where(
                  pd.Series(True, index=dataframe_1.index),
                  pd.Series(dataframe_1['new_column_30'].apply(
                      (lambda x: is_empty(x))),
                            index=dataframe_1.index),
                  pd.Series(
                      (dataframe_1['new_column_30'].astype('str').mask(
                          dataframe_1['new_column_30'].isnull(), pd.NA) !=
                       'county_weights'),
                      index=dataframe_1.index)) | pd.DataFrame.where(
                          pd.Series(True, index=dataframe_1.index),
                          pd.Series(dataframe_1['new_column_31'].apply(
                              (lambda x: is_empty(x))),
                                    index=dataframe_1.index),
                          pd.Series(
                              (dataframe_1['new_column_31'].astype('str').mask(
                                  dataframe_1['new_column_31'].isnull(), pd.NA)
                               != 'county_names_all'),
                              index=dataframe_1.index))) |
               (pd.DataFrame.where(
                   pd.Series(True, index=dataframe_1.index),
                   pd.Series(dataframe_1['new_column_32'].apply(
                       (lambda x: is_empty(x))),
                             index=dataframe_1.index),
                   pd.Series(
                       (dataframe_1['new_column_32'].astype('str').mask(
                           dataframe_1['new_column_32'].isnull(), pd.NA) !=
                        'county_fips_all'),
                       index=dataframe_1.index)) | pd.DataFrame.where(
                           pd.Series(True, index=dataframe_1.index),
                           pd.Series(dataframe_1['new_column_33'].apply(
                               (lambda x: is_empty(x))),
                                     index=dataframe_1.index),
                           pd.Series(
                               (dataframe_1['new_column_33'].astype('str').mask(
                                   dataframe_1['new_column_33'].isnull(), pd.NA)
                                != 'imprecise'),
                               index=dataframe_1.index))))
             )) | (pd.DataFrame.where(
                 pd.Series(True, index=dataframe_1.index),
                 pd.Series(dataframe_1['new_column_34'].apply(
                     (lambda x: is_empty(x))),
                           index=dataframe_1.index),
                 pd.Series(
                     (dataframe_1['new_column_34'].astype('str').mask(
                         dataframe_1['new_column_34'].isnull(), pd.NA) !=
                      'military'),
                     index=dataframe_1.index)) | pd.DataFrame.where(
                         pd.Series(True, index=dataframe_1.index),
                         pd.Series(dataframe_1['new_column_35'].apply(
                             (lambda x: is_empty(x))),
                                   index=dataframe_1.index),
                         pd.Series(
                             (dataframe_1['new_column_35'].astype('str').mask(
                                 dataframe_1['new_column_35'].isnull(), pd.NA)
                              != 'timezone'),
                             index=dataframe_1.index))))]
    dataframe_1 = pd.DataFrame({
        'new_column_18':
            dataframe_1['new_column_18'],
        'new_column_19':
            dataframe_1['new_column_19'],
        'new_column_20':
            dataframe_1['new_column_20'],
        'new_column_21':
            dataframe_1['new_column_21'],
        'new_column_22':
            dataframe_1['new_column_22'],
        'new_column_23':
            dataframe_1['new_column_23'],
        'new_column_24':
            dataframe_1['new_column_24'],
        'new_column_25':
            dataframe_1['new_column_25'],
        'new_column_26':
            dataframe_1['new_column_26'],
        'new_column_27':
            dataframe_1['new_column_27'],
        'new_column_28':
            dataframe_1['new_column_28'],
        'new_column_29':
            dataframe_1['new_column_29'],
        'new_column_30':
            dataframe_1['new_column_30'],
        'new_column_31':
            dataframe_1['new_column_31'],
        'new_column_32':
            dataframe_1['new_column_32'],
        'new_column_33':
            dataframe_1['new_column_33'],
        'new_column_34':
            dataframe_1['new_column_34'],
        'new_column_35':
            dataframe_1['new_column_35'],
        'new_column_36':
            pd.Series(dataframe_1['new_column_18'].apply(
                (lambda x: to_integer(x))),
                      dtype='Int64')
    })
    if (dataframe is None):
        dataframe = pd.read_csv('/insert/dataset/location/here/',
                                skip_blank_lines=False,
                                lineterminator='\n',
                                dtype=str,
                                encoding='UTF-8')
    dataframe.columns = ['column_18', 'column_19', 'column_20', 'column_21']
    dataframe = pd.DataFrame({
        'new_column_37':
            pd.DataFrame.where(
                pd.Series(dataframe['column_18'].str.strip().apply(
                    (lambda x: replace1.exec(x))),
                          index=dataframe.index),
                pd.Series((dataframe['column_18'].str.strip().apply(
                    (lambda x: matches1.exec(x))) &
                           dataframe['column_18'].str.strip().apply(
                               (lambda x: matches2.exec(x)))),
                          index=dataframe.index),
                pd.Series(dataframe['column_18'], index=dataframe.index)),
        'new_column_38':
            pd.DataFrame.where(
                pd.Series(dataframe['column_19'].str.strip().apply(
                    (lambda x: replace1.exec(x))),
                          index=dataframe.index),
                pd.Series((dataframe['column_19'].str.strip().apply(
                    (lambda x: matches1.exec(x))) &
                           dataframe['column_19'].str.strip().apply(
                               (lambda x: matches2.exec(x)))),
                          index=dataframe.index),
                pd.Series(dataframe['column_19'], index=dataframe.index)),
        'new_column_39':
            pd.DataFrame.where(
                pd.Series(dataframe['column_20'].str.strip().apply(
                    (lambda x: replace1.exec(x))),
                          index=dataframe.index),
                pd.Series((dataframe['column_20'].str.strip().apply(
                    (lambda x: matches1.exec(x))) &
                           dataframe['column_20'].str.strip().apply(
                               (lambda x: matches2.exec(x)))),
                          index=dataframe.index),
                pd.Series(dataframe['column_20'], index=dataframe.index)),
        'new_column_40':
            pd.DataFrame.where(
                pd.Series(dataframe['column_21'].str.strip().apply(
                    (lambda x: replace1.exec(x))),
                          index=dataframe.index),
                pd.Series((dataframe['column_21'].str.strip().apply(
                    (lambda x: matches1.exec(x))) &
                           dataframe['column_21'].str.strip().apply(
                               (lambda x: matches2.exec(x)))),
                          index=dataframe.index),
                pd.Series(dataframe['column_21'], index=dataframe.index))
    })
    dataframe = pd.DataFrame({
        'new_column_41':
            dataframe['new_column_37'].apply((lambda x: replace2.exec(x))),
        'new_column_42':
            dataframe['new_column_38'].apply((lambda x: replace2.exec(x))),
        'new_column_43':
            dataframe['new_column_39'].apply((lambda x: replace2.exec(x))),
        'new_column_44':
            dataframe['new_column_40'].apply((lambda x: replace2.exec(x)))
    })
    dataframe = dataframe.loc[(
        (pd.DataFrame.where(
            pd.Series(True, index=dataframe.index),
            pd.Series(dataframe['new_column_41'].apply((lambda x: is_empty(x))),
                      index=dataframe.index),
            pd.Series((dataframe['new_column_41'].astype('str').mask(
                dataframe['new_column_41'].isnull(), pd.NA) != 'first_name'),
                      index=dataframe.index)) |
         pd.DataFrame.where(
             pd.Series(True, index=dataframe.index),
             pd.Series(dataframe['new_column_42'].apply(
                 (lambda x: is_empty(x))),
                       index=dataframe.index),
             pd.Series((dataframe['new_column_42'].astype('str').mask(
                 dataframe['new_column_42'].isnull(), pd.NA) != 'last_name'),
                       index=dataframe.index))) |
        (pd.DataFrame.where(
            pd.Series(True, index=dataframe.index),
            pd.Series(dataframe['new_column_43'].apply((lambda x: is_empty(x))),
                      index=dataframe.index),
            pd.Series((dataframe['new_column_43'].astype('str').mask(
                dataframe['new_column_43'].isnull(), pd.NA) != 'zipcode'),
                      index=dataframe.index)) | pd.DataFrame.where(
                          pd.Series(True, index=dataframe.index),
                          pd.Series(dataframe['new_column_44'].apply(
                              (lambda x: is_empty(x))),
                                    index=dataframe.index),
                          pd.Series(
                              (dataframe['new_column_44'].astype('str').mask(
                                  dataframe['new_column_44'].isnull(), pd.NA) !=
                               'next_meter_reading'),
                              index=dataframe.index))))]
    dataframe = pd.DataFrame({
        'new_column_41':
            dataframe['new_column_41'],
        'new_column_42':
            dataframe['new_column_42'],
        'new_column_43':
            dataframe['new_column_43'],
        'new_column_44':
            dataframe['new_column_44'],
        'new_column_45':
            pd.Series(dataframe['new_column_43'].apply(
                (lambda x: to_integer(x))),
                      dtype='Int64')
    })
    return dataframe

"""
Encountered error while translating CDF to pandas. Could not complete the translation process. 
Error traceback: 
TraversalError : Failed while traversing the recipe script. 
TranslationError : Failed while translating join_transform. 
list index out of range
"""
